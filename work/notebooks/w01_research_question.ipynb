# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/StickRift/Rift/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because the starter dataset contains 30,000 content pages and 54.21% of them currently show a downward trend. The median page receives 731 impressions over 90 days, so there is measurable search visibility across the dataset and a potential need to prioritize limited review time. I want to investigate how observable search, content, freshness, and engagement signals can help prioritize which pages a human reviewer should look at first. The current downward-trend statistic is useful evidence that this problem is worth investigating, but I will not treat `trend_direction`, `trend_pct`, or the derived decline label as features in a later model. Any final target will need to be based on an appropriate observed outcome rather than a label defined from the same signals.

# %% [markdown]
# ## The question
#
# **Search question:** Which content pages should a human content or SEO reviewer prioritize for possible refresh or another action, based on observable search, content, freshness, and engagement signals?
#
# The goal is to determine whether these signals can support a useful ranked review queue, rather than to automatically decide which pages should be refreshed. The eventual ranking will need to be evaluated against an observed outcome using a predefined metric.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %% [markdown]
# ## The decision, action, and cost of a wrong call
#
# The decision is which content page should be reviewed first for a possible refresh or other action. The person acting on the recommendation would be a content or SEO reviewer who has limited time and needs to prioritize the pages most worth examining. The output would be a ranked review queue with clear reasons for why each page was prioritized. A wrong recommendation could waste the review team's time by sending them to a low-value page, or cause them to overlook a page with meaningful search visibility and a possible performance problem. Data can help because the starter dataset contains multiple signals about search visibility, traffic, engagement, content characteristics, and freshness that can be considered together. A later ML model may be useful if these signals contain patterns that are too complex for a simple hand-written rule, but that will need to be tested against a transparent baseline. The system should support human review rather than automatically deciding that a page must be refreshed. The eventual ranking will need an observed outcome and a predefined evaluation metric so that its usefulness can be tested rather than assumed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Total pages:", len(df))

print("Median impressions (90d):", df["impressions_90d"].median())

declining_pct = df["trend_direction"].eq("down").mean() * 100
print("Pages with downward trend:", round(declining_pct, 2), "%")
# Out:
# Total pages: 30000
# Median impressions (90d): 731.0
# Pages with downward trend: 54.21 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project can identify patterns in the available search, traffic, engagement, freshness, and content measurements and use them to support a ranked review list. I can make observed and directional claims about which signals are associated with pages showing weaker or declining performance. I can test whether a simple ranking or later ML model performs better than a transparent baseline. However, I cannot claim that the model proves why a page declined, that refreshing a page will definitely improve its performance, or that I am predicting Google's algorithm. Any eventual ranking should be treated as decision support for human review, not as an automatic instruction to refresh a page.

# %%
import pandas as pd

# Load the starter dataset for this check.
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# Check that the key columns needed for the framing are present.
required_columns = [
    "search_volume",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "engagement_rate",
    "days_since_last_update"
]

missing_columns = [col for col in required_columns if col not in df.columns]

print("Required signal columns present:", len(missing_columns) == 0)

if missing_columns:
    print("Missing columns:", missing_columns)
else:
    print("All required signal columns are available.")
# Out:
# Required signal columns present: True
# All required signal columns are available.

# %% [markdown]
# ## 5. Self-check
#
# Before submitting, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors
# - [ ] No client names, URLs, or private queries appear anywhere
# - [ ] My claims use careful words such as observed, measured, directional, and decision-support
# - [ ] The notebook is committed to my repo under `work/notebooks/`
