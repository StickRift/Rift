# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/StickRift/Rift/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because the starter dataset contains 30,000 content pages and 54.21% of them currently show a downward trend. The median page receives 731 impressions over 90 days, so many pages have measurable search visibility that could make review decisions useful. I want to investigate how observable search, content, freshness, and engagement signals can help prioritize which pages a human reviewer should look at first. I am treating the current downward-trend field as a starting proxy, not proof that a page will decline in the future or that refreshing it will cause recovery.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %% [markdown]
# ## The decision, action, and cost of a wrong call
#
# The decision is which content page should be reviewed first for a possible refresh or other action. The person acting on the recommendation would be a content or SEO reviewer who has limited time and needs to prioritize the pages most worth examining. A useful output would be a ranked review queue with a suggested action and clear reasons based on the available data. A wrong recommendation can waste the review team's time by sending them to a low-value page, or it can cause them to miss a page with meaningful search visibility and a genuine problem. Therefore, the system should support human review rather than automatically deciding that a page must be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Total pages:", len(df))

print("Median impressions (90d):", df["impressions_90d"].median())

declining_pct = (df["trend_direction"].eq("down").mean() * 100)
print("Pages with downward trend:", round(declining_pct, 2), "%")

print("Median days since last update:", df["days_since_last_update"].median())
# Out:
# Total pages: 30000
# Median impressions (90d): 731.0
# Pages with downward trend: 54.21 %
# Median days since last update: 20.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project can identify patterns in the available search, traffic, engagement, freshness, and content measurements and use them to support a ranked review list. I can make observed and directional claims about which signals are associated with pages that appear to need attention. I can also test whether a simple ranking or model performs better than a transparent baseline. However, I cannot claim that the model proves why a page declined, that refreshing a page will definitely improve its performance, or that I am predicting Google's algorithm. The results should be treated as decision-support recommendations that still require human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
